# %%
# importamos las librerias necesarias y las configuraciones respectivas para evitar warnings innecesarios
import pandas as pd
import datetime as dt
pd.options.mode.chained_assignment = None

# importamos el archivo con los valores de indicadores en bruto
df = pd.read_csv('indicadoreservicios.csv')
df.head(2)  

periodo_a_evaluar = 2021

# %%
# Regularizacion de municipios de parral y dalcahue
df.loc[df['id_Comp_Matriz'] == 7299, 'id_Comp_Matriz'] = 94459

# %%
import os
cwd = os.getcwd()
cwd = cwd.replace('ETL','')

# %%
df_figem = pd.read_excel(cwd +'Ranking\\FIGEM_2021_SINIM.xlsx', skiprows=23)
df_figem = df_figem[['CODIGO', 'MUNICIPIO', 'Agrupación']]
df_figem .drop(345, axis=0, inplace=True)

# %%
dfcodes = pd.read_excel(cwd +'Ranking\\municipios.xlsx')
df_mix = df_figem.merge(dfcodes, how = 'left', left_on='MUNICIPIO', right_on='Nombre subdere')
dfmix = df_mix[['CodMunChC', 'Clasificacion FIGEM']]
dfmix.head(2)
# Out:
#    CodMunChC                                Clasificacion FIGEM
# 0      88313  Grandes comunas metropolitanas con alto y/o me...
# 1      86571  Grandes comunas metropolitanas con alto y/o me...

# %%
df = df.merge(dfmix, how = 'left', left_on='id_Comp_Matriz', right_on='CodMunChC')
df.drop('CodMunChC', axis=1, inplace=True)
df
# Out:
#       id_Comp_Matriz                                           Servicio  \
# 0               6957  Central De Abastecimiento Del Sistema Nacional...
# 1               7002           Junta Nacional De Auxilio Escolar Y Beca
# 2               6954                            Fondo Nacional De Salud
# 3               7079                     Subsecretaria De Salud Publica
# 4               6954                            Fondo Nacional De Salud
# ...              ...                                                ...
# 1778         1808599      Corporación Municipal De Deporte  De Vitacura
# 1779         1801801           Corporacion De Deportes De Padre Hurtado
# 1780            7493                          Empresa Portuaria Iquique
# 1781          135959  Delegación Presidencial Provincial De Isla De ...
# 1782         1803800       Corp Municipal De Desarrollo Social De Lampa
#
#                                        Ministerio  Anio  indicador1  \
# 0                             Ministerio de Salud  2021        27.4
# 1                         Ministerio de Educación  2021        25.9
# 2                             Ministerio de Salud  2022        40.0
# 3                             Ministerio de Salud  2021        30.2
# 4                             Ministerio de Salud  2021        15.4
# ...                                           ...   ...         ...
# 1778                                        Otros  2022         0.0
# 1779                                        Otros  2022         NaN
# 1780                                        Otros  2022         0.0
# 1781  Ministerio del interior y Seguridad pública  2022         NaN
# 1782                                        Otros  2022         NaN
#
#       indicador2  indicador3  indicador4  indicador5  indicador6  ...  \
# 0            3.0         0.0   18.319783   27.533875   34.257204  ...
# 1            4.0         0.0   53.065395   14.850136   16.708540  ...
# 2            4.0        -4.0   59.760956   29.482072   14.265178  ...
# 3            4.0         0.0   17.803456   52.236012   93.235523  ...
# 4            8.0         4.0   46.796117   44.757282   57.667254  ...
# ...          ...         ...         ...         ...         ...  ...
# 1778         4.0         NaN   81.818182    0.000000    0.000000  ...
# 1779         NaN         NaN  100.000000   33.333333   85.782755  ...
# 1780         4.0         2.0  100.000000    0.000000    0.000000  ...
# 1781         NaN         NaN   71.428571    0.000000    0.000000  ...
# 1782         NaN         NaN   77.272727    0.000000    0.000000  ...
#
#       indicador31_III  indicador32_III  porComp  porTra  porAnom  porProm  \
# 0                 1.0              1.0     20.0     0.0      0.0     10.0
# 1                 1.0              1.0     13.0     0.0      0.0      6.0
# 2                 1.0              NaN     33.0     0.0     11.0     22.0
# 3                 2.0              1.0     27.0     0.0      9.0     16.0
# 4                 1.0              1.0      0.0     0.0      9.0      3.0
# ...               ...              ...      ...     ...      ...      ...
# 1778              NaN              NaN     29.0     0.0     25.0     24.0
# 1779              NaN              NaN     22.0     NaN      NaN     22.0
# 1780              NaN              NaN     60.0     0.0     12.0     40.0
# 1781              NaN              NaN     22.0     NaN      NaN     22.0
# 1782              NaN              NaN      0.0     NaN      NaN      0.0
#
#       Ministerio_y         Monto  Cantidad_licitaciones  Clasificacion FIGEM
# 0              NaN  1.030693e+12                   1859                  NaN
# 1              NaN  7.057359e+11                   1818                  NaN
# 2              NaN  4.469749e+11                    326                  NaN
# 3              NaN  4.391184e+11                  20967                  NaN
# 4              NaN  3.020744e+11                   1104                  NaN
# ...            ...           ...                    ...                  ...
# 1778           NaN  4.560400e+05                      1                  NaN
# 1779           NaN  2.533250e+05                      1                  NaN
# 1780           NaN  1.700000e+05                      1                  NaN
# 1781           NaN  1.658280e+05                      1                  NaN
# 1782           NaN  1.102870e+05                      2                  NaN
#
# [1783 rows x 74 columns]

# %%
# Definimos la función que hará el rankeo de los indicadores de cada servicio
def ranking_indicadores(df, anio):
    # Creamos una lista vacía para guardar los nombres de los indicadores
    l_ind = []
    for i in range(32):
        if i != 6:
            l_ind.append(f'indicador{i+1}')

    # Creamos una lista vacía para guardar los nombres de los indicadores rankeados
    l_rank = []
    for i in range(32):
        if i != 6:
            l_rank.append(f'indicador{i+1}_r')

    # Filtramos el df por año
    dft = df[df['Anio'] == anio]

    # Ciclo para recorrer cada indicador y calcular su ranking
    for i in range(31):
        if l_ind[i] in ['indicador2', 'indicador3', 'indicador4', 'indicador12', 'indicador13', 'indicador27']:
            dft[l_rank[i]] = dft[l_ind[i]].rank(method='min', ascending=False)
        else:
            dft[l_rank[i]] = dft[l_ind[i]].rank(method='min', ascending=True)
    
    # sub df con los valores de los indicadores rankeados para sacar promedio y calcualr nuevo rankling en base a ese promedio
    dft2 = dft[['id_Comp_Matriz', 'Clasificacion FIGEM', 'indicador1_r', 'indicador2_r', 'indicador3_r', 'indicador4_r', 'indicador5_r', 'indicador6_r', 'indicador8_r', 'indicador9_r', 'indicador10_r', 'indicador11_r', 'indicador12_r', 'indicador13_r', 'indicador14_r', 'indicador15_r', 'indicador16_r', 'indicador17_r', 'indicador18_r', 'indicador19_r', 'indicador20_r', 'indicador21_r', 'indicador22_r', 'indicador23_r', 'indicador24_r', 'indicador25_r', 'indicador26_r', 'indicador27_r', 'indicador28_r', 'indicador29_r', 'indicador30_r', 'indicador31_r', 'indicador32_r']]
    dft2['total_rank_mean'] = dft2.loc[:, 'indicador1_r':'indicador32_r'].mean(axis=1)
    dft2['final_rank'] = dft2['total_rank_mean'].rank(method='min')
    dft2 = dft2[['id_Comp_Matriz', 'total_rank_mean', 'final_rank']]
    
    # Unimo los dfs para obtener un df con los valores de los indicadores rankeados totales
    dffinal = dft.merge(dft2, on='id_Comp_Matriz')

    return dffinal

# %%
# Calculo para el Sector Municipal 
df_mun = df[df['Ministerio']=='Municipios']
df_mun_rank = pd.DataFrame()
for i in df_mun['Clasificacion FIGEM'].unique():
    df_mun_filt = df_mun[df_mun['Clasificacion FIGEM']==i]
    df_mun_rank = pd.concat([df_mun_rank, ranking_indicadores(df_mun_filt, periodo_a_evaluar)], axis=0)

df_mun_rank.head(5).sort_values(by='final_rank', ascending=True)
# Out:
#    id_Comp_Matriz                        Servicio  Ministerio  Anio  \
# 0          100155    I Municipalidad Lo Barnechea  Municipios  2021
# 4            7321       I Municipalidad De Temuco  Municipios  2021
# 2           86568     I Municipalidad De Santiago  Municipios  2021
# 1           87388  I Municipalidad De Puente Alto  Municipios  2021
# 3           86571   I Municipalidad De Las Condes  Municipios  2021
#
#    indicador1  indicador2  indicador3  indicador4  indicador5  indicador6  \
# 0        25.5         4.0        -1.0   49.221790    6.095979    6.499446
# 4        15.3         4.0         0.0   29.991338    8.813339    9.726879
# 2        15.9         5.0        -2.0   39.082504   13.833570    4.275018
# 1        20.7         4.0        -2.0   30.679262   20.332883    3.437235
# 3        25.0         4.0         0.0   34.320465   61.131676   35.335368
#
#    ...  indicador25_r  indicador26_r  indicador27_r  indicador28_r  \
# 0  ...            1.0           11.0           13.0           22.0
# 4  ...           47.0           45.0           23.0           30.0
# 2  ...           39.0            7.0            7.0           35.0
# 1  ...            1.0           41.0            4.0           20.0
# 3  ...            1.0           38.0           16.0           16.0
#
#    indicador29_r  indicador30_r  indicador31_r  indicador32_r  \
# 0            NaN           11.0           19.0            1.0
# 4            1.0           18.0           28.0            1.0
# 2            1.0            1.0            1.0            1.0
# 1           45.0           34.0           23.0            1.0
# 3            1.0           45.0           24.0            1.0
#
#    total_rank_mean  final_rank
# 0        15.200000         3.0
# 4        20.387097        18.0
# 2        20.633333        26.0
# 1        21.774194        35.0
# 3        24.451613        43.0
#
# [5 rows x 107 columns]

# %%
df_mun_rank
# Out:
#     id_Comp_Matriz                                 Servicio  Ministerio  Anio  \
# 0           100155             I Municipalidad Lo Barnechea  Municipios  2021
# 1            87388           I Municipalidad De Puente Alto  Municipios  2021
# 2            86568              I Municipalidad De Santiago  Municipios  2021
# 3            86571            I Municipalidad De Las Condes  Municipios  2021
# 4             7321                I Municipalidad De Temuco  Municipios  2021
# ..             ...                                      ...         ...   ...
# 91          115302                I Municipalidad De Papudo  Municipios  2021
# 92          116407  Ilustre Municipalidad De Cabo De Hornos  Municipios  2021
# 93          115457     I Municipalidad De San Jose De Maipo  Municipios  2021
# 94          114914             I Municipalidad De Vichuquen  Municipios  2021
# 95          117585             I Municipalidad De Primavera  Municipios  2021
#
#     indicador1  indicador2  indicador3  indicador4  indicador5  indicador6  \
# 0         25.5         4.0        -1.0   49.221790    6.095979    6.499446
# 1         20.7         4.0        -2.0   30.679262   20.332883    3.437235
# 2         15.9         5.0        -2.0   39.082504   13.833570    4.275018
# 3         25.0         4.0         0.0   34.320465   61.131676   35.335368
# 4         15.3         4.0         0.0   29.991338    8.813339    9.726879
# ..         ...         ...         ...         ...         ...         ...
# 91        35.7         3.0        -6.0   53.061224    9.353741   13.042308
# 92        50.9         2.0        -2.0   35.064935   42.337662   27.459876
# 93        75.0         2.0         0.0   59.174312   32.568807   29.599543
# 94        72.7         1.0        -2.0   36.085627   71.712538   60.864113
# 95        37.5         2.0         0.0   43.589744   81.318681   32.401606
#
#     ...  indicador25_r  indicador26_r  indicador27_r  indicador28_r  \
# 0   ...            1.0           11.0           13.0           22.0
# 1   ...            1.0           41.0            4.0           20.0
# 2   ...           39.0            7.0            7.0           35.0
# 3   ...            1.0           38.0           16.0           16.0
# 4   ...           47.0           45.0           23.0           30.0
# ..  ...            ...            ...            ...            ...
# 91  ...            1.0           66.0           45.0           79.0
# 92  ...            1.0           66.0           45.0           93.0
# 93  ...            1.0           66.0           19.0            1.0
# 94  ...            1.0           66.0           45.0            1.0
# 95  ...            1.0           66.0           45.0           94.0
#
#     indicador29_r  indicador30_r  indicador31_r  indicador32_r  \
# 0             NaN           11.0           19.0            1.0
# 1            45.0           34.0           23.0            1.0
# 2             1.0            1.0            1.0            1.0
# 3             1.0           45.0           24.0            1.0
# 4             1.0           18.0           28.0            1.0
# ..            ...            ...            ...            ...
# 91            1.0           31.0           83.0            NaN
# 92            1.0           21.0            1.0            NaN
# 93            NaN           96.0            NaN            1.0
# 94            1.0            1.0           73.0            NaN
# 95            1.0            1.0            1.0            NaN
#
#     total_rank_mean  final_rank
# 0         15.200000         3.0
# 1         21.774194        35.0
# 2         20.633333        26.0
# 3         24.451613        43.0
# 4         20.387097        18.0
# ..              ...         ...
# 91        43.633333        70.0
# 92        54.896552        94.0
# 93        46.333333        77.0
# 94        51.178571        88.0
# 95        48.571429        83.0
#
# [348 rows x 107 columns]

# %%
# Calculo para el Sector Administración Central 
df_ac = df[df['Ministerio'].str.lower().str.contains('ministerio')]
df_ac = df_ac[~df_ac['Servicio'].str.lower().str.contains('público')]
df_ac_rank = ranking_indicadores(df_ac, periodo_a_evaluar)
df_ac_rank.head(5).sort_values(by='final_rank', ascending=True)
# Out:
#    id_Comp_Matriz                                           Servicio  \
# 0            6957  Central De Abastecimiento Del Sistema Nacional...
# 1            7002           Junta Nacional De Auxilio Escolar Y Beca
# 3            6954                            Fondo Nacional De Salud
# 2            7079                     Subsecretaria De Salud Publica
# 4            7242  Ministerio De Obras Publicas Direc Cion Gral D...
#
#                      Ministerio  Anio  indicador1  indicador2  indicador3  \
# 0           Ministerio de Salud  2021        27.4         3.0         0.0
# 1       Ministerio de Educación  2021        25.9         4.0         0.0
# 3           Ministerio de Salud  2021        15.4         8.0         4.0
# 2           Ministerio de Salud  2021        30.2         4.0         0.0
# 4  Ministerio de Obras Públicas  2021        28.1         3.0         0.0
#
#    indicador4  indicador5  indicador6  ...  indicador25_r  indicador26_r  \
# 0   18.319783   27.533875   34.257204  ...            1.0            7.0
# 1   53.065395   14.850136   16.708540  ...            1.0          122.0
# 3   46.796117   44.757282   57.667254  ...          451.0          298.0
# 2   17.803456   52.236012   93.235523  ...            1.0          251.0
# 4   18.734911   59.005311   40.131197  ...          457.0          165.0
#
#    indicador27_r  indicador28_r  indicador29_r  indicador30_r  indicador31_r  \
# 0          221.0          198.0            NaN          109.0          100.0
# 1           55.0          210.0            1.0          132.0          160.0
# 3           82.0          213.0            1.0          233.0          205.0
# 2          185.0          404.0          257.0          230.0          275.0
# 4          140.0          444.0            1.0          298.0          242.0
#
#    indicador32_r  total_rank_mean  final_rank
# 0            1.0       141.666667        36.0
# 1            1.0       155.483871        77.0
# 3            1.0       162.483871       107.0
# 2            1.0       207.419355       356.0
# 4          223.0       300.387097       462.0
#
# [5 rows x 107 columns]

# %%
df_mun_rank.sort_values(by='final_rank').head(5)
# Out:
#     id_Comp_Matriz                       Servicio  Ministerio  Anio  \
# 44          116411  I Municipalidad De Pitrufquen  Municipios  2021
# 6            86872     I Municipalidad De Copiapo  Municipios  2021
# 80          165106     I Municipalidad De Codegua  Municipios  2021
# 59          142855   I Municipalidad De San Pedro  Municipios  2021
# 38           87402  I Municipalidad De Valparaiso  Municipios  2021
#
#     indicador1  indicador2  indicador3  indicador4  indicador5  indicador6  \
# 44        18.6         5.0        -2.0   46.166667   18.234804   12.032573
# 6         21.8         7.0         1.0   27.486376   36.376022   10.138664
# 80        40.7         3.0         1.0   53.289474   19.078947   14.247600
# 59        41.9         3.0        -1.0   58.295282   20.091324   13.223431
# 38        14.9         4.0         0.0   56.728538   15.661253   48.799588
#
#     ...  indicador25_r  indicador26_r  indicador27_r  indicador28_r  \
# 44  ...            1.0           33.0           10.0           10.0
# 6   ...            1.0            8.0            7.0            5.0
# 80  ...            1.0           33.0           42.0            1.0
# 59  ...            1.0           17.0           13.0           37.0
# 38  ...            1.0            6.0           35.0           18.0
#
#     indicador29_r  indicador30_r  indicador31_r  indicador32_r  \
# 44            1.0            5.0           24.0            NaN
# 6             1.0           14.0           10.0            1.0
# 80            1.0           34.0            1.0            1.0
# 59            1.0           61.0            1.0            NaN
# 38            1.0           15.0            1.0            1.0
#
#     total_rank_mean  final_rank
# 44        15.300000         1.0
# 6         12.580645         1.0
# 80        19.419355         1.0
# 59        24.700000         1.0
# 38        14.161290         1.0
#
# [5 rows x 107 columns]

# %%
dfmun1 = df_mun_rank[['id_Comp_Matriz', 'Servicio',  'Ministerio',  'Anio',  'indicador1_r',  'indicador2_r', 'indicador3_r', 'indicador4_r', 'indicador5_r', 'indicador6_r', 'indicador8_r', 'indicador9_r', 'indicador10_r', 'indicador11_r', 'indicador12_r', 'indicador13_r', 'indicador14_r', 'indicador15_r', 'indicador16_r', 'indicador17_r', 'indicador18_r', 'indicador19_r', 'indicador20_r', 'indicador21_r', 'indicador22_r', 'indicador23_r', 'indicador24_r', 'indicador25_r', 'indicador26_r', 'indicador27_r', 'indicador28_r', 'indicador29_r', 'indicador30_r', 'indicador31_r', 'indicador32_r', 'final_rank', 'total_rank_mean', 'Clasificacion FIGEM']]
dfmun2 = df_mun_rank[['id_Comp_Matriz', 'Servicio',  'Ministerio',  'Anio',  'indicador1',  'indicador2', 'indicador3', 'indicador4', 'indicador5', 'indicador6', 'indicador8', 'indicador9', 'indicador10', 'indicador11', 'indicador12', 'indicador13', 'indicador14', 'indicador15', 'indicador16', 'indicador17', 'indicador18', 'indicador19', 'indicador20', 'indicador21', 'indicador22', 'indicador23', 'indicador24', 'indicador25', 'indicador26', 'indicador27', 'indicador28', 'indicador29', 'indicador30', 'indicador31', 'indicador32', 'final_rank', 'total_rank_mean', 'Clasificacion FIGEM']]

dfmunmelted1 = pd.melt(dfmun1, id_vars=['id_Comp_Matriz',	'Servicio',	'Ministerio',	'Anio', 'final_rank', 'total_rank_mean', 'Clasificacion FIGEM'])
dfmunmelted2 = pd.melt(dfmun2, id_vars=['id_Comp_Matriz',	'Servicio',	'Ministerio',	'Anio', 'final_rank', 'total_rank_mean', 'Clasificacion FIGEM'])

dfmunmelted1['variable'] = dfmunmelted1['variable'].str.replace('_r', '')

dfmunmelted = dfmunmelted1.merge(dfmunmelted2, on=['id_Comp_Matriz',	'Servicio',	'Ministerio',	'Anio', 'final_rank', 'total_rank_mean', 'variable', 'Clasificacion FIGEM'])

dfmunmelted.rename(columns={'value_x': 'Ranking Indicador', 'value_y':'Valor Indicador'}, inplace=True)

# %%
dfmunmelted.loc[dfmunmelted['variable'] == 'indicador1', 'variable'] = 'Porcentaje de licitaciones públicas y privadas con un único oferente'
dfmunmelted.loc[dfmunmelted['variable'] == 'indicador2', 'variable'] = 'Promedio de participantes por procedimiento'
dfmunmelted.loc[dfmunmelted['variable'] == 'indicador3', 'variable'] = 'Cambio en el promedio de participantes por procedimiento'
dfmunmelted.loc[dfmunmelted['variable'] == 'indicador4', 'variable'] = 'Número de empresas ganadoras diferentes entre todos los contratos'
dfmunmelted.loc[dfmunmelted['variable'] == 'indicador5', 'variable'] = 'Porcentaje de procedimientos que utilizaron adjudicación directa o licitación privada'
dfmunmelted.loc[dfmunmelted['variable'] == 'indicador6', 'variable'] = 'Porcentaje del monto adjudicado por adjudicación directa o licitación privada'
dfmunmelted.loc[dfmunmelted['variable'] == 'indicador8', 'variable'] = 'IHH por número de contratos'
dfmunmelted.loc[dfmunmelted['variable'] == 'indicador9', 'variable'] = 'IHH por monto'
dfmunmelted.loc[dfmunmelted['variable'] == 'indicador10', 'variable'] = 'ID por número de contratos'
dfmunmelted.loc[dfmunmelted['variable'] == 'indicador11', 'variable'] = 'ID por monto'
dfmunmelted.loc[dfmunmelted['variable'] == 'indicador12', 'variable'] = 'Índice de participación'
dfmunmelted.loc[dfmunmelted['variable'] == 'indicador13', 'variable'] = 'Número de participantes distintos entre todos los procedimientos'
dfmunmelted.loc[dfmunmelted['variable'] == 'indicador14', 'variable'] = 'Índice de concentración de las 4 empresas con más procedimientos ganados'
dfmunmelted.loc[dfmunmelted['variable'] == 'indicador15', 'variable'] = 'Índice de concentración de las 4 empresas con más monto adjudicado'
dfmunmelted.loc[dfmunmelted['variable'] == 'indicador16', 'variable'] = 'Ratio de participación y adjudicación en licitaciones públicas y privadas'
dfmunmelted.loc[dfmunmelted['variable'] == 'indicador17', 'variable'] = 'Porcentaje de licitaciones públicas y privadas sin ningún documento obligatorio publicado'
dfmunmelted.loc[dfmunmelted['variable'] == 'indicador18', 'variable'] = 'Promedio del porcentaje de incumplimiento en la publicación de documentos obligatorios'
dfmunmelted.loc[dfmunmelted['variable'] == 'indicador19', 'variable'] = 'Porcentaje de licitaciones públicas y privadas con varias adjudicaciones'
dfmunmelted.loc[dfmunmelted['variable'] == 'indicador20', 'variable'] = 'Porcentaje de las licitaciones mayores o iguales a 100 UTM y menores a 1.000 UTM cuyo plazo de oferta fue acelerado'
dfmunmelted.loc[dfmunmelted['variable'] == 'indicador21', 'variable'] = 'Porcentaje de las licitaciones mayores o iguales a 1.000 UTM y menores a 5.000 UTM cuyo plazo de oferta fue acelerado'
dfmunmelted.loc[dfmunmelted['variable'] == 'indicador22', 'variable'] = 'Porcentaje de licitaciones sin bases de licitación'
dfmunmelted.loc[dfmunmelted['variable'] == 'indicador23', 'variable'] = 'Porcentaje de licitaciones sin respuesta a todas las preguntas del foro'
dfmunmelted.loc[dfmunmelted['variable'] == 'indicador24', 'variable'] = 'Porcentaje de procedimientos sin acta de evaluación'
dfmunmelted.loc[dfmunmelted['variable'] == 'indicador25', 'variable'] = 'Porcentaje de procedimientos sin resolución de adjudicación'
dfmunmelted.loc[dfmunmelted['variable'] == 'indicador26', 'variable'] = 'Porcentaje de procedimientos sin contrato'
dfmunmelted.loc[dfmunmelted['variable'] == 'indicador27', 'variable'] = 'Cambio en el porcentaje de contratos publicados por procedimiento'
dfmunmelted.loc[dfmunmelted['variable'] == 'indicador28', 'variable'] = 'Porcentaje de licitaciones que no cumplen con la normativa de publicación'
dfmunmelted.loc[dfmunmelted['variable'] == 'indicador29', 'variable'] = 'Porcentaje de las licitaciones menores a 100 UTM cuyo plazo de oferta fue menor al plazo mínimo establecido por la ley de compras públicas'
dfmunmelted.loc[dfmunmelted['variable'] == 'indicador30', 'variable'] = 'Porcentaje de las licitaciones mayores o iguales a 100 UTM y menores a 1.000 UTM cuyo plazo de oferta fue menor al plazo mínimo establecido por la ley de compras públicas'
dfmunmelted.loc[dfmunmelted['variable'] == 'indicador31', 'variable'] = 'Porcentaje de las licitaciones mayores o iguales a 1.000 UTM y menores a 5.000 UTM cuyo plazo de oferta fue menor al plazo mínimo establecido por la ley de compras públicas'
dfmunmelted.loc[dfmunmelted['variable'] == 'indicador32', 'variable'] = 'Porcentaje de las licitaciones mayores o iguales a 5.000 UTM cuyo plazo de oferta fue menor al plazo mínimo establecido por la ley de compras públicas'

# %%
dfmunmelted.to_excel('municipios_rank2.xlsx', index=False)

# %%
dfmunmelted.sort_values(by='Servicio', ascending=False).head(34)
# Out:
#        id_Comp_Matriz                   Servicio  Ministerio  Anio  \
# 7782           115163  Municipalidad De Traiguen  Municipios  2021
# 2562           115163  Municipalidad De Traiguen  Municipios  2021
# 6738           115163  Municipalidad De Traiguen  Municipios  2021
# 10566          115163  Municipalidad De Traiguen  Municipios  2021
# 8826           115163  Municipalidad De Traiguen  Municipios  2021
# 9522           115163  Municipalidad De Traiguen  Municipios  2021
# 3606           115163  Municipalidad De Traiguen  Municipios  2021
# 6390           115163  Municipalidad De Traiguen  Municipios  2021
# 5346           115163  Municipalidad De Traiguen  Municipios  2021
# 4998           115163  Municipalidad De Traiguen  Municipios  2021
# 2910           115163  Municipalidad De Traiguen  Municipios  2021
# 2214           115163  Municipalidad De Traiguen  Municipios  2021
# 10218          115163  Municipalidad De Traiguen  Municipios  2021
# 4650           115163  Municipalidad De Traiguen  Municipios  2021
# 3954           115163  Municipalidad De Traiguen  Municipios  2021
# 474            115163  Municipalidad De Traiguen  Municipios  2021
# 126            115163  Municipalidad De Traiguen  Municipios  2021
# 1518           115163  Municipalidad De Traiguen  Municipios  2021
# 8478           115163  Municipalidad De Traiguen  Municipios  2021
# 5694           115163  Municipalidad De Traiguen  Municipios  2021
# 7086           115163  Municipalidad De Traiguen  Municipios  2021
# 9870           115163  Municipalidad De Traiguen  Municipios  2021
# 7434           115163  Municipalidad De Traiguen  Municipios  2021
# 8130           115163  Municipalidad De Traiguen  Municipios  2021
# 9174           115163  Municipalidad De Traiguen  Municipios  2021
# 1170           115163  Municipalidad De Traiguen  Municipios  2021
# 3258           115163  Municipalidad De Traiguen  Municipios  2021
# 822            115163  Municipalidad De Traiguen  Municipios  2021
# 6042           115163  Municipalidad De Traiguen  Municipios  2021
# 1866           115163  Municipalidad De Traiguen  Municipios  2021
# 4302           115163  Municipalidad De Traiguen  Municipios  2021
# 3490            84149  Municipalidad De Pudahuel  Municipios  2021
# 4186            84149  Municipalidad De Pudahuel  Municipios  2021
# 1402            84149  Municipalidad De Pudahuel  Municipios  2021
#
#        final_rank  total_rank_mean  \
# 7782         36.0        25.483871
# 2562         36.0        25.483871
# 6738         36.0        25.483871
# 10566        36.0        25.483871
# 8826         36.0        25.483871
# 9522         36.0        25.483871
# 3606         36.0        25.483871
# 6390         36.0        25.483871
# 5346         36.0        25.483871
# 4998         36.0        25.483871
# 2910         36.0        25.483871
# 2214         36.0        25.483871
# 10218        36.0        25.483871
# 4650         36.0        25.483871
# 3954         36.0        25.483871
# 474          36.0        25.483871
# 126          36.0        25.483871
# 1518         36.0        25.483871
# 8478         36.0        25.483871
# 5694         36.0        25.483871
# 7086         36.0        25.483871
# 9870         36.0        25.483871
# 7434         36.0        25.483871
# 8130         36.0        25.483871
# 9174         36.0        25.483871
# 1170         36.0        25.483871
# 3258         36.0        25.483871
# 822          36.0        25.483871
# 6042         36.0        25.483871
# 1866         36.0        25.483871
# 4302         36.0        25.483871
# 3490         45.0        26.096774
# 4186         45.0        26.096774
# 1402         45.0        26.096774
#
#                                      Clasificacion FIGEM  \
# 7782     Comunas urbanas medianas, con desarrollo medio.
# 2562     Comunas urbanas medianas, con desarrollo medio.
# 6738     Comunas urbanas medianas, con desarrollo medio.
# 10566    Comunas urbanas medianas, con desarrollo medio.
# 8826     Comunas urbanas medianas, con desarrollo medio.
# 9522     Comunas urbanas medianas, con desarrollo medio.
# 3606     Comunas urbanas medianas, con desarrollo medio.
# 6390     Comunas urbanas medianas, con desarrollo medio.
# 5346     Comunas urbanas medianas, con desarrollo medio.
# 4998     Comunas urbanas medianas, con desarrollo medio.
# 2910     Comunas urbanas medianas, con desarrollo medio.
# 2214     Comunas urbanas medianas, con desarrollo medio.
# 10218    Comunas urbanas medianas, con desarrollo medio.
# 4650     Comunas urbanas medianas, con desarrollo medio.
# 3954     Comunas urbanas medianas, con desarrollo medio.
# 474      Comunas urbanas medianas, con desarrollo medio.
# 126      Comunas urbanas medianas, con desarrollo medio.
# 1518     Comunas urbanas medianas, con desarrollo medio.
# 8478     Comunas urbanas medianas, con desarrollo medio.
# 5694     Comunas urbanas medianas, con desarrollo medio.
# 7086     Comunas urbanas medianas, con desarrollo medio.
# 9870     Comunas urbanas medianas, con desarrollo medio.
# 7434     Comunas urbanas medianas, con desarrollo medio.
# 8130     Comunas urbanas medianas, con desarrollo medio.
# 9174     Comunas urbanas medianas, con desarrollo medio.
# 1170     Comunas urbanas medianas, con desarrollo medio.
# 3258     Comunas urbanas medianas, con desarrollo medio.
# 822      Comunas urbanas medianas, con desarrollo medio.
# 6042     Comunas urbanas medianas, con desarrollo medio.
# 1866     Comunas urbanas medianas, con desarrollo medio.
# 4302     Comunas urbanas medianas, con desarrollo medio.
# 3490   Grandes comunas metropolitanas con alto y/o me...
# 4186   Grandes comunas metropolitanas con alto y/o me...
# 1402   Grandes comunas metropolitanas con alto y/o me...
#
#                                                 variable  Ranking Indicador  \
# 7782   Porcentaje de procedimientos sin acta de evalu...                1.0
# 2562                                       IHH por monto               24.0
# 6738   Porcentaje de las licitaciones mayores o igual...               50.0
# 10566  Porcentaje de las licitaciones mayores o igual...                1.0
# 8826   Cambio en el porcentaje de contratos publicado...               47.0
# 9522   Porcentaje de las licitaciones menores a 100 U...                1.0
# 3606                             Índice de participación               38.0
# 6390   Porcentaje de las licitaciones mayores o igual...               40.0
# 5346   Porcentaje de licitaciones públicas y privadas...                1.0
# 4998   Ratio de participación y adjudicación en licit...               50.0
# 2910                          ID por número de contratos               16.0
# 2214                         IHH por número de contratos               26.0
# 10218  Porcentaje de las licitaciones mayores o igual...               50.0
# 4650   Índice de concentración de las 4 empresas con ...               29.0
# 3954   Número de participantes distintos entre todos ...               10.0
# 474          Promedio de participantes por procedimiento               17.0
# 126    Porcentaje de licitaciones públicas y privadas...               39.0
# 1518   Porcentaje de procedimientos que utilizaron ad...               43.0
# 8478           Porcentaje de procedimientos sin contrato               45.0
# 5694   Promedio del porcentaje de incumplimiento en l...               34.0
# 7086   Porcentaje de licitaciones sin bases de licita...               21.0
# 9870   Porcentaje de las licitaciones mayores o igual...               41.0
# 7434   Porcentaje de licitaciones sin respuesta a tod...               22.0
# 8130   Porcentaje de procedimientos sin resolución de...                1.0
# 9174   Porcentaje de licitaciones que no cumplen con ...               18.0
# 1170   Número de empresas ganadoras diferentes entre ...               19.0
# 3258                                        ID por monto               22.0
# 822    Cambio en el promedio de participantes por pro...                2.0
# 6042   Porcentaje de licitaciones públicas y privadas...               22.0
# 1866   Porcentaje del monto adjudicado por adjudicaci...               42.0
# 4302   Índice de concentración de las 4 empresas con ...               18.0
# 3490                             Índice de participación               25.0
# 4186   Índice de concentración de las 4 empresas con ...               28.0
# 1402   Porcentaje de procedimientos que utilizaron ad...               28.0
#
#        Valor Indicador
# 7782          0.000000
# 2562        279.051968
# 6738         81.820000
# 10566         0.000000
# 8826         -2.860000
# 9522          0.000000
# 3606          3.286000
# 6390         50.880000
# 5346          0.000000
# 4998          2.630000
# 2910          0.008398
# 2214         61.901759
# 10218        81.820000
# 4650         26.528569
# 3954          2.700000
# 474           4.000000
# 126          39.100000
# 1518         28.644501
# 8478         97.140000
# 5694         25.227273
# 7086          2.730000
# 9870         50.880000
# 7434          2.730000
# 8130          0.000000
# 9174          2.730000
# 1170         43.771331
# 3258          0.030022
# 822           0.000000
# 6042         10.000000
# 1866         21.415255
# 4302          8.840701
# 3490          4.167000
# 4186         10.602094
# 1402         17.350993
